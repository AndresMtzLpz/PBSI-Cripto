# %%
#AES Key Expansion
#El programa usa la clave proporcionada como entrada, genera las palabras clave correspondientes w0 - w43 como se indica en la tabla a cmd

sbox = []

Rcon = [0x00000000, 0x01000000, 0x02000000,
		0x04000000, 0x08000000, 0x10000000, 
		0x20000000, 0x40000000, 0x80000000, 
		0x1b000000, 0x36000000]
		
def keyExpansion(key):
  #preparar la lista w para contener 44 tuplas
  w = [()]*44
  #llenar las primeras 4 palabras según la clave
  for i in range(4):
    w[i] = (key[4*i], key[4*i+1], key[4*i+2], key[4*i+3])
    print("w",i,":",*w[i])
    
  #Llenar el resto basado en las palabras, rotword, subword y rcon
  for i in range(4, 44):
    #obtener las palabra clave anterior
    temp = w[i-1]
    word = w[i-4]

    if i % 4 == 0:
      x = RotWord(temp)
      y = SubWord(x)
      rcon = Rcon[int(i/4)]
      temp = hexor(y, hex(rcon)[2:])
      print("")
      print("RotWord ",*x)
      print("SubWord ",y)
      print("Rcon ",rcon)
      print("Rcon + XOR ",temp)
      print("#######################")
      print("")

    #creando cadenas de hexadecimal en lugar de tupla
    word = ''.join(word)
    temp = ''.join(temp)
		
    #xor de los dos valores hexadecimales
    xord = hexor(word, temp)
    w[i] = (xord[:2], xord[2:4], xord[4:6], xord[6:8])
    
    print('w',i,':',*w[i])
    
  return w
	
def hexor(hex1, hex2):
	bin1 = hex2binary(hex1)
	bin2 = hex2binary(hex2)
	
	xord = int(bin1, 2) ^ int(bin2, 2)
	
	#prefijo
	hexed = hex(xord)[2:]
	
	#los 0 iniciales se cortan arriba, si no son de longitud 8, agregue un 0 inicial
	if len(hexed) != 8:
		hexed = '0' + hexed
		
	return hexed
	
def hex2binary(hex):
	return bin(int(str(hex), 16))

def RotWord(word):
	return word[1:] + word[:1]
		

def SubWord(word):
	sWord = ()
	
	for i in range(4):
		
		#verifica si el primer carácter es una letra, obtiene el decimal correspondiente; de lo contrario, toma el valor y agrega 1
		if word[i][0].isdigit() == False:
			row = ord(word[i][0]) - 86
		else:
			row = int(word[i][0])+1

		if word[i][1].isdigit() == False:
			col = ord(word[i][1]) - 86
		else:
			col = int(word[i][1])+1
		
		sBoxIndex = (row*16) - (17-col)
		
		piece = hex(sbox[sBoxIndex])[2:]
		
		#verifica la longitud para no se olvidar ceros iniciales
		if len(piece) != 2:
			piece = '0' + piece
		
		sWord = (*sWord, piece)
		
	return ''.join(sWord)

def main():
  key = ["2b", "7e", "15", "16", "28", "ae", "d2", "a6", "ab", "f7", "15", "88", "09", "cf", "4f", "3c"]
  print("Llave provista: " + "".join(key))
  print("")
	
  w = keyExpansion(key)
	
if __name__ == '__main__':
  
	main()
# Out:
# Llave provista: 2b7e151628aed2a6abf7158809cf4f3c
#
# w 0 : 2b 7e 15 16
# w 1 : 28 ae d2 a6
# w 2 : ab f7 15 88
# w 3 : 09 cf 4f 3c
#
# RotWord  cf 4f 3c 09
# SubWord  8a84eb01
# Rcon  16777216
# Rcon + XOR  8b84eb01
# #######################
#
# w 4 : a0 fa fe 17
# w 5 : 88 54 2c b1
# w 6 : 23 a3 39 39
# w 7 : 2a 6c 76 05
#
# RotWord  6c 76 05 2a
# SubWord  50386be5
# Rcon  33554432
# Rcon + XOR  52386be5
# #######################
#
# w 8 : f2 c2 95 f2
# w 9 : 7a 96 b9 43
# w 10 : 59 35 80 7a
# w 11 : 73 59 f6 7f
#
# RotWord  59 f6 7f 73
# SubWord  cb42d28f
# Rcon  67108864
# Rcon + XOR  cf42d28f
# #######################
#
# w 12 : 3d 80 47 7d
# w 13 : 47 16 fe 3e
# w 14 : 1e 23 7e 44
# w 15 : 6d 7a 88 3b
#
# RotWord  7a 88 3b 6d
# SubWord  dac4e23c
# Rcon  134217728
# Rcon + XOR  d2c4e23c
# #######################
#
# w 16 : ef 44 a5 41
# w 17 : a8 52 5b 7f
# w 18 : b6 71 25 3b
# w 19 : db 0b ad 00
#
# RotWord  0b ad 00 db
# SubWord  2b9563b9
# Rcon  268435456
# ...
